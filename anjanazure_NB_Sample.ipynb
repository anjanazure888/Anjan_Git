# %%
spark.conf.set("fs.azure.account.key.anjanazure888dbstorage.dfs.core.windows.net","sv=2026-02-06&ss=bfqt&srt=c&sp=rwdlacupyx&se=2026-09-11T15:09:44Z&st=2026-09-11T12:54:44Z&spr=https&sig=EaMcgLBnqwciCJV6ffFz8R3qyKtoT7NYhorgSi6gYaA%3D")

# %%
sas_token = spark.conf.get("fs.azure.account.key.anjanazure888dbstorage.dfs.core.windows.net")
spark.conf.set("fs.azure.account.auth.type.anjanazure888dbstorage.dfs.core.windows.net", "SAS")
spark.conf.set("fs.azure.sas.token.provider.type.anjanazure888dbstorage.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.sas.FixedSASTokenProvider")
spark.conf.set("fs.azure.sas.fixed.token.anjanazure888dbstorage.dfs.core.windows.net", sas_token)
# display(dbutils.fs.ls("abfss://anjanazure888bronze@anjanazure888dbstorage.dfs.core.windows.net"))

# %%
spark.conf.set("fs.azure.account.key.anjanazure888dbstorage.dfs.core.windows.net","sv=2026-02-06&ss=bfqt&srt=c&sp=rwdlacupyx&se=2026-09-11T00:04:45Z&st=2026-09-10T15:49:45Z&spr=https&sig=%2F%2FCVcBvK97hn5owasKA12%2FLxw8VVyvOx2RxlUYsx3pk%3D")

# %%
dbutils.fs.ls("abfss://anjanazure888bronze@anjanazure888dbstorage.dfs.core.windows.net")

# %%
dbutils.fs.ls("abfss://deletecontainer@anjanazure888dbstorage.dfs.core.windows.net")

# %%
display(dbutils.fs.ls("abfss://deletecontainer@anjanazure888dbstorage.dfs.core.windows.net"))

# %%
display(dbutils.fs.ls("abfss://anjanazure888bronze@anjanazure888dbstorage.dfs.core.windows.net"))
